# %%
print('hello khushi')
# Out:
# hello khushi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Setup Complete!")
# Out:
# Setup Complete!

# %%
name = "Khushi"
SCGP = 8.27
print("THE RESULT OF SEMESTER 5 : "+ name,SCGP)
# Out:
# THE RESULT OF SEMESTER 5 : Khushi 8.27
