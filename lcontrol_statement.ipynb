# %%
'''
Python supports 2 types of iterative statements. 
 
1. for loop -
        Syntax: 
 
    for x in sequence : 
    #code
2 . while loop
'''
name="Khushi Navik"   
for x in name :   
    print(x)
# Out:
# K
# h
# u
# s
# h
# i
#
# N
# a
# v
# i
# k
