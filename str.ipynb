# %%
'''
string 3 characterstics

1- immutable
2- indexed
3- iterable


#indexing
text = "python"
print(text [0]) #+ve left to right
print(text[-1]) #-ve indexing right to lef

print(text[100])
'''
a = "python"
print(a[0])
print(a[-2])
# Out:
# p
# o

# %%
#len()
password = "123_kdjcn"

if len(password) > 5:
    print('login successfull')

else:
    print('lenght is too short or <5')
# Out:
# login successfull

# %%
#slicing
'''
start,stop,step
'''
a = "py t hon"
print(a[0:5])
# Out:
# py t

# %%
'''
lower()
'''
a = "PYTHON"
print(a.lower())
'''
upper()
'''
a = "python"
print(a.upper())
# Out:
# python
# PYTHON
