# %%
'''
list -
    ordered
    mutable
    dynamic
    heterogenous

'''
#square brackets []
# my_list = [2,4455,'k',True]


# list constructor(())
my_con = ((2,4455,'k',True))
print(my_con)
# Out:
# (2, 4455, 'k', True)

# %%
lst = [1,2,3,4,5] 
print(f'Before list {lst}') 
lst [0] = 'hello' 
print(f'After list {lst}')
# Out:
# Before list [1, 2, 3, 4, 5]
# After list ['hello', 2, 3, 4, 5]

# %%
#update list

my_list = [1,2,3,4,5]
#by slicing
my_list[0:3]=10,20,30
print(my_list)
# Out:
# [10, 20, 30, 4, 5]
