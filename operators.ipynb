# %%
'''
PEMDAS
P  → Parentheses () 1ST PRORITY
E  → Exponent **2ND PRORITY
M  → Multiply * OR % 3RD PRORITY
D  → Divide /
A  → Add + 4TH PRORITY
S  → Subtract -
'''


print(3*3+3/3-3) #PEMDAS
print(3*(3+3)/3-3) #PEMDAS
print(3*3+3/3-3) #PEMDAS
# Out:
# 7.0
# 3.0
# 7.0
